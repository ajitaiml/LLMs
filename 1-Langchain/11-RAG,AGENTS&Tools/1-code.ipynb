# %%
import torch

# For PyTorch
print("CUDA Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA Available: True
# GPU Name: NVIDIA GeForce GTX 1650

# %%
# PyTorch
import torch
print("PyTorch CUDA Available:", torch.cuda.is_available())
print("PyTorch GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

# TensorFlow
import tensorflow as tf
print("TensorFlow GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# PyTorch CUDA Available: True
# PyTorch GPU Name: NVIDIA GeForce GTX 1650
# TensorFlow GPUs Available: 0
